# %% [markdown]
# # funciones mas comunes en numpy

# %%
import numpy as np

# %% [markdown]
# > shape y reshape

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[9, 2],
#        [5, 6],
#        [9, 4]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[9, 2, 5, 6, 9, 4]])

# %% [markdown]
# > maximos  y argmax

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([16,  4, 11,  7, 14, 12, 17,  5,  6, 12])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[16,  4, 11,  7, 14],
#        [12, 17,  5,  6, 12]])

# %%
print(matriz)
# Out:
# [[16  4 11  7 14]
#  [12 17  5  6 12]]

# %%
arr.max()
# Out:
# 17

# %%
matriz.max()
# Out:
# 17

# %%
matriz.max(1)
# Out:
# array([16, 17])

# %%
matriz.argmax()
# Out:
# 6

# %% [markdown]
# maximo de cada fila

# %%
matriz.argmax(1)
# Out:
# array([0, 1])

# %% [markdown]
# maximo de cada columna

# %%
matriz.argmax(0)
# Out:
# array([0, 1, 0, 0, 0])

# %% [markdown]
# > sort

# %%
arr.sort()
arr
# Out:
# array([ 4,  5,  6,  7, 11, 12, 12, 14, 16, 17])

# %% [markdown]
# > mediana

# %%
np.median(arr)
# Out:
# 11.5

# %% [markdown]
# > desviacion estandar

# %%
np.std(arr)
# Out:
# 4.409081537009721
