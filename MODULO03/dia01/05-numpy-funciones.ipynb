# %% [markdown]
# # funciones mas comunes en numpy

# %%
import numpy as np

# %% [markdown]
# > shape y reshape

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[3, 4],
#        [8, 4],
#        [8, 8]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[3, 4, 8, 4, 8, 8]])

# %% [markdown]
# > maximos  y argmax

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([18, 18,  5,  6,  6, 18,  3, 17, 11, 18])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[18, 18,  5,  6,  6],
#        [18,  3, 17, 11, 18]])

# %%
print(matriz)
# Out:
# [[18 18  5  6  6]
#  [18  3 17 11 18]]

# %%
arr.max()
# Out:
# 18

# %%
matriz.max()
# Out:
# 18

# %%
matriz.max(1)
# Out:
# array([18, 18])

# %%
matriz.argmax()
# Out:
# 0

# %% [markdown]
# maximo de cada fila

# %%
matriz.argmax(1)
# Out:
# array([0, 0])

# %% [markdown]
# maximo de cada columna

# %%
matriz.argmax(0)
# Out:
# array([0, 0, 1, 1, 1])

# %% [markdown]
# > sort

# %%
arr.sort()
arr
# Out:
# array([ 3,  5,  6,  6, 11, 17, 18, 18, 18, 18])

# %% [markdown]
# > mediana

# %%
np.median(arr)
# Out:
# 14.0

# %% [markdown]
# > desviacion estandar

# %%
np.std(arr)
# Out:
# 6.099180272790763
