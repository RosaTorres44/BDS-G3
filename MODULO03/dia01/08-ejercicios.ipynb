# %% [markdown]
# se instala yahoo finance

# %%
# !pip install urllib3 websockets --upgrade
# !pip install yahoo-fin
# Out:
# ...
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# ...
#   Using cached websockets-10.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# ...
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Using cached websockets-10.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (107 kB)
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install requests_html

# %%
from yahoo_fin import stock_info as si
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# jalamos data de bitcoin a dolares de un par de años

# %%
data = si.get_data('BTC-USD', start_date = '2022-01-01', end_date='2024-12-31')
data
# Out:
#                     open          high           low         close  \
# 2022-01-01  46311.746094  47827.312500  46288.484375  47686.812500
# 2022-01-02  47680.925781  47881.406250  46856.937500  47345.218750
# 2022-01-03  47343.542969  47510.726562  45835.964844  46458.117188
# 2022-01-04  46458.851562  47406.546875  45752.464844  45897.574219
# 2022-01-05  45899.359375  46929.046875  42798.222656  43569.003906
# ...                  ...           ...           ...           ...
# 2024-12-27  95704.976562  97294.843750  93310.742188  94164.859375
# 2024-12-28  94160.187500  95525.898438  94014.289062  95163.929688
# 2024-12-29  95174.054688  95174.875000  92881.789062  93530.226562
# 2024-12-30  93527.195312  94903.320312  91317.132812  92643.210938
# 2024-12-31  92643.250000  96090.601562  91914.031250  93429.203125
#
#                 adjclose       volume   ticker
# 2022-01-01  47686.812500  24582667004  BTC-USD
# 2022-01-02  47345.218750  27951569547  BTC-USD
# ...

# %%
dates = np.array(data.index, dtype='datetime64[D]')
dates
# Out:
# array(['2022-01-01', '2022-01-02', '2022-01-03', ..., '2024-12-29',
#        '2024-12-30', '2024-12-31'], dtype='datetime64[D]')

# %%
closing_price = np.array(data['close'])
closing_price
# Out:
# array([47686.8125   , 47345.21875  , 46458.1171875, ..., 93530.2265625,
#        92643.2109375, 93429.203125 ])

# %%
plt.figure(figsize=(12,6))
plt.title='Tendencia del precio de bitcoin en dolares'
plt.plot(dates,closing_price , label='Precio de Cierre', color='blue' )
plt.xlabel("fecha",fontsize=12)
plt.ylabel("precio cierre USD",fontsize=12)
plt.grid=True
plt.legend()
plt.show()
