# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df_books = pd.read_csv('/content/drive/MyDrive/Notebooks_Colaborate/archivos/libros.csv')
df_books.head(2)
# Out:
# Mounted at /content/drive
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# agrupar por campos.
# el campo autor se vuelve el indice

# %%
df_books.groupby('Author').count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %% [markdown]
# reseteo de indices

# %%
df_books.groupby('Author').count().reset_index()
# Out:
#                          Author  Name  User Rating  Reviews  Price  Year  \
# 0              Abraham Verghese     2            2        2      2     2
# 1                Adam Gasiewski     1            1        1      1     1
# 2                 Adam Mansbach     1            1        1      1     1
# 3                     Adir Levy     1            1        1      1     1
# 4    Admiral William H. McRaven     1            1        1      1     1
# ..                          ...   ...          ...      ...    ...   ...
# 243             Walter Isaacson     3            3        3      3     3
# 244               William Davis     2            2        2      2     2
# 245            William P. Young     2            2        2      2     2
# 246            Wizards RPG Team     3            3        3      3     3
# 247                Zhi Gang Sha     2            2        2      2     2
#
#      Genre
# 0        2
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# ...

# %% [markdown]
# agrega el minimo y el maximo de cada columna

# %%
df_books.groupby('Author').agg(['min','max']).reset_index()
# Out:
#                          Author  \
#
# 0              Abraham Verghese
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  \
#                                                    min
# 0                                    Cutting for Stone
# 1    Milk and Vine: Inspirational Quotes From Class...
# 2                                 Go the F**k to Sleep
# 3    What Should Danny Do? (The Power to Choose Ser...
# 4    Make Your Bed: Little Things That Can Change Y...
# ..                                                 ...
# 243                                  Leonardo da Vinci
# 244  Wheat Belly: Lose the Wheat, Lose the Weight, ...
# ...

# %%
df_books.groupby('Author').agg({'Reviews':['min','max'],'User Rating':['count']}).reset_index()
# Out:
#                          Author Reviews        User Rating
#                                     min    max       count
# 0              Abraham Verghese    4866   4866           2
# 1                Adam Gasiewski    3113   3113           1
# 2                 Adam Mansbach    9568   9568           1
# 3                     Adir Levy    8170   8170           1
# 4    Admiral William H. McRaven   10199  10199           1
# ..                          ...     ...    ...         ...
# 243             Walter Isaacson    3014   7827           3
# 244               William Davis    7497   7497           2
# 245            William P. Young   19720  19720           2
# 246            Wizards RPG Team   16990  16990           3
# 247                Zhi Gang Sha      37    220           2
#
# [248 rows x 4 columns]

# %%
df_books.groupby(['Year','Genre']).count()
# Out:
#                   Name  Author  User Rating  Reviews  Price
# Year Genre
# 2009 Fiction        24      24           24       24     24
#      Non Fiction    26      26           26       26     26
# 2010 Fiction        20      20           20       20     20
#      Non Fiction    30      30           30       30     30
# 2011 Fiction        21      21           21       21     21
#      Non Fiction    29      29           29       29     29
# 2012 Fiction        21      21           21       21     21
#      Non Fiction    29      29           29       29     29
# 2013 Fiction        24      24           24       24     24
#      Non Fiction    26      26           26       26     26
# 2014 Fiction        29      29           29       29     29
#      Non Fiction    21      21           21       21     21
# 2015 Fiction        17      17           17       17     17
#      Non Fiction    33      33           33       33     33
# ...

# %%
df_books.groupby(['Year', 'Genre'])['Author'].count().head(5).reset_index()
# Out:
#    Year        Genre  Author
# 0  2009      Fiction      24
# 1  2009  Non Fiction      26
# 2  2010      Fiction      20
# 3  2010  Non Fiction      30
# 4  2011      Fiction      21

# %%
df_books.groupby(['Year', 'Genre'])['Author'].nunique().head(5).reset_index()
# Out:
#    Year        Genre  Author
# 0  2009      Fiction      16
# 1  2009  Non Fiction      23
# 2  2010      Fiction      13
# 3  2010  Non Fiction      30
# 4  2011      Fiction      16
